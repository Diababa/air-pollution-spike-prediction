# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv("data/processed/train.csv")
print(df.head())
# Out:
#               datetime  pm25  temperature  humidity  wind_speed  \
# 0  2023-04-29 00:00:00   7.1         10.5        95         8.9
# 1  2023-04-29 01:00:00   8.1          9.8        97         7.0
# 2  2023-04-29 02:00:00   8.2          8.9        98         5.5
# 3  2023-04-29 03:00:00   8.1          8.5        98         6.1
# 4  2023-04-29 04:00:00   8.9          8.1        99         5.4
#
#    wind_direction  lag_1  lag_3  lag_6  lag_12  lag_24  lag_48  \
# 0             328    6.7    8.3    4.8     4.1     4.7    10.2
# 1             325    7.1    7.6    5.4     4.3     4.4     9.7
# 2             328    8.1    6.7    7.1     4.3     3.8    10.9
# 3             332    8.2    7.1    8.3     4.1     3.9    13.2
# 4             323    8.1    8.1    7.6     3.9     3.9    14.2
#
#    rolling_mean_24  rolling_std_24  temp_x_humidity  hour  day_of_week  month  \
# 0         4.883333        1.392735            997.5     0            5      4
# ...

# %%
print(df.describe())
# Out:
#                pm25   temperature      humidity    wind_speed  wind_direction  \
# count  26208.000000  26208.000000  26208.000000  26208.000000    26208.000000
# mean      10.778060     12.809741     76.931967     11.757719      190.062653
# std        7.849008      6.901510     16.632094      6.259995       98.248248
# min        1.500000     -5.800000     15.000000      0.000000        0.000000
# 25%        5.700000      8.100000     67.000000      7.100000      117.000000
# 50%        8.300000     12.400000     81.000000     10.600000      207.000000
# 75%       13.300000     17.500000     90.000000     15.400000      263.000000
# max       87.300000     38.300000    100.000000     47.300000      360.000000
#
#               lag_1         lag_3         lag_6        lag_12       lag_24  \
# count  26208.000000  26208.000000  26208.000000  26208.000000  26208.00000
# mean      10.777969     10.777953     10.777999     10.777614     10.77360
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26208 entries, 0 to 26207
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         26208 non-null  object
#  1   pm25             26208 non-null  float64
#  2   temperature      26208 non-null  float64
#  3   humidity         26208 non-null  int64
#  4   wind_speed       26208 non-null  float64
#  5   wind_direction   26208 non-null  int64
#  6   lag_1            26208 non-null  float64
#  7   lag_3            26208 non-null  float64
#  8   lag_6            26208 non-null  float64
#  9   lag_12           26208 non-null  float64
#  10  lag_24           26208 non-null  float64
#  11  lag_48           26208 non-null  float64
#  12  rolling_mean_24  26208 non-null  float64
#  13  rolling_std_24   26208 non-null  float64
#  14  temp_x_humidity  26208 non-null  float64
#  15  hour             26208 non-null  int64
# ...

# %%
df = pd.read_csv("data/raw/pollution_weather.csv")
print(df.head())
# Out:
#               datetime  pm25  temperature  humidity  wind_speed  \
# 0  2023-04-27 00:00:00  10.2          8.9        87         5.5
# 1  2023-04-27 01:00:00   9.7          9.0        87         5.1
# 2  2023-04-27 02:00:00  10.9          7.7        91         6.4
# 3  2023-04-27 03:00:00  13.2          7.7        90         5.1
# 4  2023-04-27 04:00:00  14.2          6.8        92         5.9
#
#    wind_direction
# 0              79
# 1              86
# 2              63
# 3              82
# 4              79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26304 entries, 0 to 26303
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   datetime        26304 non-null  object
#  1   pm25            26304 non-null  float64
#  2   temperature     26304 non-null  float64
#  3   humidity        26304 non-null  int64
#  4   wind_speed      26304 non-null  float64
#  5   wind_direction  26304 non-null  int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                pm25   temperature      humidity    wind_speed  wind_direction
# count  26304.000000  26304.000000  26304.000000  26304.000000    26304.000000
# mean      10.770784     12.818898     76.868385     11.749551      189.813374
# std        7.838740      6.896380     16.708440      6.254334       98.363884
# min        1.500000     -5.800000     14.000000      0.000000        0.000000
# 25%        5.700000      8.100000     67.000000      7.100000      116.000000
# 50%        8.300000     12.400000     81.000000     10.600000      207.000000
# 75%       13.300000     17.500000     90.000000     15.400000      262.000000
# max       87.300000     38.300000    100.000000     47.300000      360.000000
